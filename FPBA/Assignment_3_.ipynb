# %%
# Importing Pandas and Matplotlib for data viewing and visualisation
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Loading the file as a database
df = pd.read_csv('hotel_bookings.csv')

# %%
# Changing the file's name to Data for easier code
data = pd.read_csv('./hotel_bookings.csv')

# %%
# Viewing Data
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel          0.0      342.0             2015.0
# 1       Resort Hotel          0.0      737.0             2015.0
# 2       Resort Hotel          0.0        7.0             2015.0
# 3       Resort Hotel          0.0       13.0             2015.0
# 4       Resort Hotel          0.0       14.0             2015.0
# ...              ...          ...        ...                ...
# 119389    City Hotel          0.0       23.0             2017.0
# 119390    City Hotel          0.0      102.0             2017.0
# 119391    City Hotel          0.0       34.0             2017.0
# 119392    City Hotel          0.0      109.0             2017.0
# 119393    City Hotel          0.0      205.0             2017.0
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                      27.0
# 1                    July                      27.0
# ...

# %%
# Laying it out in different way to see other statistics
data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119388.000000  119393.000000      119315.000000
# mean        0.370431     104.010872        2016.156753
# std         0.482922     106.861793           0.707499
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119315.000000              119315.000000
# mean                  27.166165                  15.799078
# std                   13.604996                   8.780512
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
# Adding new cancellation category for ease of code
data['did_they_cancel'] = data['is_canceled'] == 1

# %%
data.loc[(data['did_they_cancel'] == 1) & (data['is_canceled'] == 1)]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 8       Resort Hotel          1.0       85.0             2015.0
# 9       Resort Hotel          1.0       75.0             2015.0
# 10      Resort Hotel          1.0       23.0             2015.0
# 27      Resort Hotel          1.0       60.0             2015.0
# 32      Resort Hotel          1.0       96.0             2015.0
# ...              ...          ...        ...                ...
# 110284    City Hotel          1.0      132.0             2017.0
# 111359    City Hotel          1.0        4.0             2017.0
# 111928    City Hotel          1.0        7.0             2017.0
# 111929    City Hotel          1.0        6.0             2017.0
# 117299    City Hotel          1.0        0.0             2017.0
#
#        arrival_date_month  arrival_date_week_number  \
# 8                    July                      27.0
# 9                    July                      27.0
# ...

# %%
# Calculating the mean lead times of those who cancelled and didn't cancel
average_lead_time_cancelled = df[df['is_canceled'] == 1]['lead_time'].mean()
average_lead_time_not_cancelled = df[df['is_canceled'] == 0]['lead_time'].mean()

# %%
#Finding the total mean adr for the whole data and naming it
mean_adr = df['adr'].mean()
mean_adr
# Out:
# np.float64(101.8305574355452)

# %%
# Finding the average lead time of those who payed above and those who payed below the average adr 
high_adr = df[df['adr'] > mean_adr]
low_adr = df[df['adr'] < mean_adr]

average_lead_time_high_adr = high_adr['lead_time'].mean()
average_lead_time_low_adr = low_adr['lead_time'].mean()

# %%
# Taking the values of each calculation
print(f"The average lead time for people who paid a daily rate above the average is: {average_lead_time_high_adr:.2f} days")
print(f"The average lead time for people who paid a daily rate below the average is: {average_lead_time_low_adr:.2f} days")
print(f"The average lead time for customers who cancelled their booking is: {average_lead_time_cancelled:.2f} days")
print(f"The average lead time for customers who did not cancel is: {average_lead_time_not_cancelled:.2f} days")
# Out:
# The average lead time for people who paid a daily rate above the average is: 95.40 days
# The average lead time for people who paid a daily rate below the average is: 110.27 days
# The average lead time for customers who cancelled their booking is: 144.85 days
# The average lead time for customers who did not cancel is: 79.99 days

# %%
# Giving the categories to create a bar chart with the data
categories = ['Above Average ADR', 'Below Average ADR', 'Not Cancelled', 'Cancelled']
average_lead_times = [average_lead_time_high_adr, average_lead_time_low_adr, average_lead_time_not_cancelled, 
                      average_lead_time_cancelled]

# %%
# Creating the bar chart
plt.figure(figsize=(10, 6))
plt.bar(categories, average_lead_times, color=['green', 'red', 'tab:cyan', 'tab:purple'])

plt.xlabel('Category')
plt.ylabel('Average Lead Time (Days)')
plt.title('Comparison of Average Lead Time for Revenue-Based Categories');

#Naming Bar Chart for Markdown
plt.savefig('rev_bar_chart.png')

# %% [markdown]
# The question I have chosen is "How does lead time impact revenue streams in the booking industry". I believe that this is important as it can reveal key factors in making profit for businesses, and help them to make decisions moving forward. Lead time is one of the best ways to compare clients as it isn't unique to any singular destination, time, hotel or anything else, allowing for an easy method to analyse operations. For this I required only the lead time, whether they cancelled or not, and the Average Daily Rate (ADR) of the customers. I chose this data specifically as I was looking at revenue, and both ADR and cancellations have major implications on profit and revenue. ![Bar chart](rev_bar_chart.png)The results, shown in this bar chart highlighted that people who paid below the average ADR, generally had a higher lead time than the people who paid above. Similiarly, the average lead time of those who cancelled was significantly higher than those who didn't. These results draw the conclusion that having shorter lead times may generate more financial success for businesses, which they could capitalize on by incentivising customers to book closer to arrival dates, with things like promotions and deals.

# %% [markdown]
# Overall mark: 55
#
# #### Business Question:
# The business question is clearly stated and relevant to the given dataset. The importance of the question to the hotel industry is also explained. However, the way answering the question does not fully utilize the data's potential, as the straightforward lead time, cancel or not and ADR are the only focused attributes. The implications for the business derived from data is inadequate and can be directly seen from the chosen variables. For example, the higher average lead time (days) for the below ADR group might simply because a lower price is offered when booking early. Consider to add more logical reasoning.
#
# <u> Pass </u>
#
# #### Data
# Three variables: lead time, cancel or not and ADR, are primarily focused to analyze the business question. The rationale of choosing these variables needs to be presented more clearly. Splitting the data into different groups shows good understanding of data pre-processing. However, the creation of a new binary variabe "did_they_cancel" seems to be redundant.
#
# <u> Good </u>
#
# #### Visualization
# A basic bar chart is used for the visualization purpose, with essential elements of title, axis labels and ticks. The above/ below average ADR category and the not cancelled / cancelled group is not comparable in a same bar chart, which may cause misinterpretation. Consider to use an extra plot to show different categories separately.
#
# <u> Pass </u>
#
# #### Code
# The code structure is clear overall and is easy to follow, except that there is a minor issue in importing the data file ('hotel_bookings(1) (1).csv' may only works on your machine. Use the non-modified file name 'hotel_bookings.csv' instead). Also, changing the file's name to data for easier code: data = pd.read_csv('./hotel_bookings.csv') is absolutely unnecessary, you can just work with df. Commments for the code are provided where necessary, which is good.
#
# <u> Good </u>
